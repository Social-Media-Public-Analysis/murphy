# %% [markdown]
# # Grouping all tweets by their users

# %%
# import bz2
# from typing import List, Union
# from glob import glob
# from os import path
# from pathlib import Path
# import json
# from glob import glob
# from os import path
# from typing import List

# import dask.bag as db

# %%
from dask.distributed import Client

client = Client(dashboard_address='0.0.0.0:6784')
client
# Out:
# <Client: 'tcp://127.0.0.1:51098' processes=4 threads=16, memory=34.27 GB>

# %%
from murpheus import DataLoading

# %%
dl = DataLoading()
dl

# %%
bags_of_tweets = dl._get_twitter_data_as_bags(file_find_expression = '/mnt/c/Users/aliab/Google_Drive/Work/Projects/SMPA/data/**/*.bz2')
bags_of_tweets.take(1)
# Out:
# ({'created_at': 'Mon Jun 01 06:29:00 +0000 2020',
#   'id': 1267342365427032065,
#   'id_str': '1267342365427032065',
#   'text': 'ダルすぎて全身の力抜いてるし出かけるけど携帯しか手にしてない',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1174569236292755458,
#    'id_str': '1174569236292755458',
#    'name': 'こうや💸金欠💰',
#    'screen_name': 'Ko_uya_15',
#    'location': 'お別れはブロ解',
#    'url': None,
#    'description': 'うしさせを自分のペースで箱推しな雑多/絵を模索中🤔/Sub🔑【@kouya_sub_15】',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 264,
#    'friends_count': 120,
#    'listed_count': 9,
#    'favourites_count': 5146,
#    'statuses_count': 4588,
#    'created_at': 'Thu Sep 19 06:21:52 +0000 2019',
# ...

# %%
dataframe_of_tweets = bags_of_tweets.to_dataframe()
dataframe_of_tweets = dataframe_of_tweets[dataframe_of_tweets['lang'] == 'en']
dataframe_of_tweets
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object
# ...

# %%
list(dataframe_of_tweets.columns.values)
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'source',
#  'truncated',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'quote_count',
#  'reply_count',
#  'retweet_count',
#  'favorite_count',
#  'entities',
#  'favorited',
#  'retweeted',
#  'filter_level',
#  'lang',
#  'timestamp_ms']

# %%
sample = dataframe_of_tweets.head()
sample
# Out:
#                         created_at                   id               id_str  \
# 9   Mon Jun 01 06:29:00 +0000 2020  1267342365431382017  1267342365431382017
# 11  Mon Jun 01 06:29:00 +0000 2020  1267342365427150849  1267342365427150849
# 14  Mon Jun 01 06:29:00 +0000 2020  1267342365452206080  1267342365452206080
# 16  Mon Jun 01 06:29:00 +0000 2020  1267342365431181312  1267342365431181312
# 17  Mon Jun 01 06:29:00 +0000 2020  1267342365439729664  1267342365439729664
#
#                                                  text  \
# 9   RT @isabelleprimave: DON'T feel bad that you c...
# 11  There's beauty at the end of the struggle. Jus...
# 14  RT @shockWilliams20: It’s past midnight but so...
# 16  RT @juliacarriew: A decent number of Facebook ...
# 17  RT @Mohamed34018605: Retweet 🔃 🔃 🔃 \n#مقاطعه_ا...
#
#                                                source  truncated  \
# 9   <a href="http://twitter.com/download/iphone" r...      False
# ...

# %%
dataframe_of_tweets['user_name'] = dataframe_of_tweets['user'].apply(lambda x: x['screen_name'], meta=str)
dataframe_of_tweets
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms user_name
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object    object
# ...

# %%
dataframe_of_tweets.shape[0].compute()
# Out:
# 1974416

# %%
# %%timeit
df.groupby('user_name').apply(lambda x: list(x['entities']), meta=list).to_csv('user_data_all/*.csv')
# Out:
# distributed.nanny - WARNING - Restarting worker
