# %%
from murpheus import DataLoading
from dask.distributed import Client
from emoji import UNICODE_EMOJI
import re

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:46827' processes=4 threads=4, memory=16.69 GB>

# %%
tweet_df = DataLoading().get_twitter_data_as_bags('../data/06/**/*').to_dataframe()
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
# Dask Name: to_dataframe, 4233 tasks

# %%
# selecting only the english language
tweet_df = tweet_df[tweet_df['lang'] == 'en']
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...
# Dask Name: getitem, 8466 tasks

# %%
# removing all of the tweets that are truncated
tweet_df['is_full_tweet'] = tweet_df.apply(lambda x: x['text'][-1] != '…', axis=1, meta=bool)
tweet_df = tweet_df[tweet_df['is_full_tweet']]
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms is_full_tweet
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object          bool
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
# Dask Name: getitem, 14110 tasks

# %%
# checking to see if there's an emoji in the text
def is_emoji(s):
    count = 0
    for emoji in UNICODE_EMOJI:
        count += s.count(emoji)
        if count > 1:
            return False
    return bool(count)

tweet_df = tweet_df[tweet_df['text'].apply(is_emoji, meta=bool)]
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms is_full_tweet
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object          bool
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...
# Dask Name: getitem, 18343 tasks

# %%
# getting emoji's from the texts and how many tweets there are

def extract_emojis(s):
    return ''.join(c for c in s if c in UNICODE_EMOJI)

tweet_df['emojis'] = tweet_df.apply(lambda x: extract_emojis(x['text']), axis=1, meta=str)
tweet_df['emojis_count'] = tweet_df.apply(lambda x: len(x['emojis']), meta=int, axis=1)
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms is_full_tweet  emojis emojis_count
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object          bool  object        int64
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...
# Dask Name: assign, 23987 tasks

# %%
# removing @RT from all of the tweets
tweet_df['text_without_retweets'] = tweet_df['text'].apply(lambda x: re.sub(r'RT @(.+?):', '', x), meta=str)
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms is_full_tweet  emojis emojis_count text_without_retweets
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object          bool  object        int64                object
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
# Dask Name: assign, 28220 tasks

# %%
# getting only tweets with one emoji
tweet_df = tweet_df[tweet_df['emojis_count'] == 1]
tweet_df
# Out:
# Dask DataFrame Structure:
#                  created_at     id  id_str    text  source truncated in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str in_reply_to_screen_name    user     geo coordinates   place contributors is_quote_status quote_count reply_count retweet_count favorite_count entities favorited retweeted filter_level    lang timestamp_ms is_full_tweet  emojis emojis_count text_without_retweets
# npartitions=1411
#                      object  int64  object  object  object      bool                object                    object              object                  object                  object  object  object      object  object       object            bool       int64       int64         int64          int64   object      bool      bool       object  object       object          bool  object        int64                object
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
# ...                     ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
#                         ...    ...     ...     ...     ...       ...                   ...                       ...                 ...                     ...                     ...     ...     ...         ...     ...          ...             ...         ...         ...           ...            ...      ...       ...       ...          ...     ...          ...           ...     ...          ...                   ...
# Dask Name: getitem, 32453 tasks

# %%
tweet_df[['text_without_retweets', 'emojis']].shape[0].compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-21670f2add2c> in <module>
# ----> 1 tweet_df[['text_without_retweets', 'emojis']].shape[0].compute()
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     277         dask.base.compute
#     278         """
# --> 279         (result,) = compute(self, traverse=False, **kwargs)
#     280         return result
#     281
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     559         postcomputes.append(x.__dask_postcompute__())
#     560
# --> 561     results = schedule(dsk, keys, **kwargs)
#     562     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     563
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2679                     should_rejoin = False
#    2680             try:
# -> 2681                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2682             finally:
#    2683                 for f in futures.values():
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1988             else:
#    1989                 local_worker = None
# -> 1990             return self.sync(
#    1991                 self._gather,
#    1992                 futures,
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     834             return future
#     835         else:
# --> 836             return sync(
#     837                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     838             )
#
# ~/miniconda3/envs/murphy/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     335     else:
#     336         while not e.is_set():
# --> 337             e.wait(10)
#     338     if error[0]:
#     339         typ, exc, tb = error[0]
#
# ~/miniconda3/envs/murphy/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/miniconda3/envs/murphy/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
